# %% [markdown]
# # Proyecto Alexis_Blockbuster

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
actores=pd.read_csv('../data/actor.csv')

actores.head()
# empiezo leyendo todos los csv
# Out:
#    actor_id first_name     last_name          last_update
# 0         1   PENELOPE       GUINESS  2006-02-15 04:34:33
# 1         2       NICK      WAHLBERG  2006-02-15 04:34:33
# 2         3         ED         CHASE  2006-02-15 04:34:33
# 3         4   JENNIFER         DAVIS  2006-02-15 04:34:33
# 4         5     JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33

# %%
categorias=pd.read_csv('../data/category.csv')

categorias.head()
# Out:
#    category_id       name          last_update
# 0            1     Action  2006-02-15 04:46:27
# 1            2  Animation  2006-02-15 04:46:27
# 2            3   Children  2006-02-15 04:46:27
# 3            4   Classics  2006-02-15 04:46:27
# 4            5     Comedy  2006-02-15 04:46:27

# %%
peliculas=pd.read_csv('../data/film.csv')

peliculas.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                   NaN                6         0.99      86
# 1            1                   NaN                3         4.99      48
# 2            1                   NaN                7         2.99      50
# 3            1                   NaN                5         2.99     117
# ...

# %%
inventario=pd.read_csv('../data/inventory.csv')

inventario.head()
# Out:
#    inventory_id  film_id  store_id          last_update
# 0             1        1         1  2006-02-15 05:09:17
# 1             2        1         1  2006-02-15 05:09:17
# 2             3        1         1  2006-02-15 05:09:17
# 3             4        1         1  2006-02-15 05:09:17
# 4             5        1         2  2006-02-15 05:09:17

# %%
lenguaje=pd.read_csv('../data/language.csv')

lenguaje.head()
# Out:
#    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19

# %%
antiguo=pd.read_csv('../data/old_HDD.csv')

antiguo.head()
# Out:
#   first_name last_name                  title  release_year  category_id
# 0   PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1   PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2   PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3   PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4   PENELOPE   GUINESS          CHEAPER CLYDE          2006           14

# %%
alquileres=pd.read_csv('../data/rental.csv')

alquileres.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2005-05-24 22:53:30           367          130
# 1          2  2005-05-24 22:54:33          1525          459
# 2          3  2005-05-24 23:03:39          1711          408
# 3          4  2005-05-24 23:04:41          2452          333
# 4          5  2005-05-24 23:05:21          2079          222
#
#            return_date  staff_id          last_update
# 0  2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1  2005-05-28 19:40:33         1  2006-02-15 21:30:53
# 2  2005-06-01 22:12:39         1  2006-02-15 21:30:53
# 3  2005-06-03 01:43:41         2  2006-02-15 21:30:53
# 4  2005-06-02 04:33:21         1  2006-02-15 21:30:53

# %%
alquileres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rental_id     1000 non-null   int64
#  1   rental_date   1000 non-null   object
#  2   inventory_id  1000 non-null   int64
#  3   customer_id   1000 non-null   int64
#  4   return_date   1000 non-null   object
#  5   staff_id      1000 non-null   int64
#  6   last_update   1000 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 54.8+ KB

# %%
actores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   actor_id     200 non-null    int64
#  1   first_name   200 non-null    object
#  2   last_name    200 non-null    object
#  3   last_update  200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   film_id               1000 non-null   int64
#  1   title                 1000 non-null   object
#  2   description           1000 non-null   object
#  3   release_year          1000 non-null   int64
#  4   language_id           1000 non-null   int64
#  5   original_language_id  0 non-null      float64
#  6   rental_duration       1000 non-null   int64
#  7   rental_rate           1000 non-null   float64
#  8   length                1000 non-null   int64
#  9   replacement_cost      1000 non-null   float64
#  10  rating                1000 non-null   object
#  11  special_features      1000 non-null   object
#  12  last_update           1000 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB

# %%
peliculas
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
actores.shape  
nan_cols = actores.isna().sum()

nan_cols[nan_cols>0]
# compruebo que no tengo nulos
# Out:
# Series([], dtype: int64)

# %%
categorias.shape  
nan_cols = categorias.isna().sum()

nan_cols[nan_cols>0]
# compruebo que no tengo nulos
# Out:
# Series([], dtype: int64)

# %%
peliculas.shape  
nan_cols = peliculas.isna().sum()

nan_cols[nan_cols>0]
# Aqui hay nulos
# Out:
# original_language_id    1000
# dtype: int64

# %%
inventario.shape  
nan_cols = inventario.isna().sum()

nan_cols[nan_cols>0]
# compruebo que no tengo nulos
# Out:
# Series([], dtype: int64)

# %%
lenguaje.shape  
nan_cols = lenguaje.isna().sum()

nan_cols[nan_cols>0]
# compruebo que no tengo nulos
# Out:
# Series([], dtype: int64)

# %%
antiguo.shape  
nan_cols = antiguo.isna().sum()

nan_cols[nan_cols>0]
# compruebo que no tengo nulos
# Out:
# Series([], dtype: int64)

# %%
alquileres.shape  
nan_cols = alquileres.isna().sum()

nan_cols[nan_cols>0]
# compruebo que no tengo nulos
# Out:
# Series([], dtype: int64)

# %%
peliculas
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
peliculas.tail(40)
# Out:
#      film_id                   title  \
# 960      961           WASH HEAVENLY
# 961      962        WASTELAND DIVINE
# 962      963             WATCH TRACY
# 963      964  WATERFRONT DELIVERANCE
# 964      965      WATERSHIP FRONTIER
# 965      966          WEDDING APOLLO
# 966      967        WEEKEND PERSONAL
# 967      968           WEREWOLF LOLA
# 968      969               WEST LION
# 969      970     WESTWARD SEABISCUIT
# 970      971            WHALE BIKINI
# 971      972         WHISPERER GIANT
# 972      973               WIFE TURN
# 973      974             WILD APOLLO
# 974      975            WILLOW TRACY
# 975      976            WIND PHANTOM
# 976      977             WINDOW SIDE
# 977      978           WISDOM WORKER
# 978      979           WITCHES PANIC
# 979      980      WIZARD COLDBLOODED
# 980      981           WOLVES DESIRE
# 981      982            WOMEN DORADO
# 982      983               WON DARES
# 983      984          WONDERFUL DROP
# ...

# %%
peliculas.language_id.unique()
# Out:
# array([1], dtype=int64)

# %%
peliculas = peliculas.drop(['original_language_id'], axis=1)
#borro la columna original_language_id ya que tiene todos nulos y no me sirve para nada

# %%
peliculas.columns
# Out:
# Index(['film_id', 'title', 'description', 'release_year', 'language_id',
#        'rental_duration', 'rental_rate', 'length', 'replacement_cost',
#        'rating', 'special_features', 'last_update'],
#       dtype='object')

# %%
antiguo.columns
# Out:
# Index(['first_name', 'last_name', 'title', 'release_year', 'category_id'], dtype='object')

# %%
antiguo.columns = antiguo.columns.str.title()
# pongo las titulos de mis columnas comenzando por mayusculula

# %%
antiguo.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Title', 'Release_Year', 'Category_Id'], dtype='object')

# %%
actores.columns
# Out:
# Index(['actor_id', 'first_name', 'last_name', 'last_update'], dtype='object')

# %%
actores.columns = actores.columns.str.title()

# %%
actores.columns
# Out:
# Index(['Actor_Id', 'First_Name', 'Last_Name', 'Last_Update'], dtype='object')

# %%
categorias.columns
# Out:
# Index(['category_id', 'name', 'last_update'], dtype='object')

# %%
categorias.columns = categorias.columns.str.title()

# %%
peliculas.columns
# Out:
# Index(['film_id', 'title', 'description', 'release_year', 'language_id',
#        'rental_duration', 'rental_rate', 'length', 'replacement_cost',
#        'rating', 'special_features', 'last_update'],
#       dtype='object')

# %%
peliculas.columns = peliculas.columns.str.title()

# %%
inventario.columns
# Out:
# Index(['inventory_id', 'film_id', 'store_id', 'last_update'], dtype='object')

# %%
inventario.columns = inventario.columns.str.title()

# %%
lenguaje.columns
# Out:
# Index(['language_id', 'name', 'last_update'], dtype='object')

# %%
lenguaje.columns = lenguaje.columns.str.title()

# %%
alquileres.columns
# Out:
# Index(['rental_id', 'rental_date', 'inventory_id', 'customer_id',
#        'return_date', 'staff_id', 'last_update'],
#       dtype='object')

# %%
alquileres.columns = alquileres.columns.str.title()

# %%
actores["First_Name"] = actores["First_Name"].str.title()
actores["Last_Name"] = actores["Last_Name"].str.title()
actores
# Out:
#      Actor_Id First_Name     Last_Name          Last_Update
# 0           1   Penelope       Guiness  2006-02-15 04:34:33
# 1           2       Nick      Wahlberg  2006-02-15 04:34:33
# 2           3         Ed         Chase  2006-02-15 04:34:33
# 3           4   Jennifer         Davis  2006-02-15 04:34:33
# 4           5     Johnny  Lollobrigida  2006-02-15 04:34:33
# ..        ...        ...           ...                  ...
# 195       196       Bela        Walken  2006-02-15 04:34:33
# 196       197      Reese          West  2006-02-15 04:34:33
# 197       198       Mary        Keitel  2006-02-15 04:34:33
# 198       199      Julia       Fawcett  2006-02-15 04:34:33
# 199       200      Thora        Temple  2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
peliculas["Title"] = peliculas["Title"].str.title()

# %%
actores.columns
# Out:
# Index(['Actor_Id', 'First_Name', 'Last_Name', 'Last_Update'], dtype='object')

# %%
actores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Actor_Id     200 non-null    int64
#  1   First_Name   200 non-null    object
#  2   Last_Name    200 non-null    object
#  3   Last_Update  200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film_Id           1000 non-null   int64
#  1   Title             1000 non-null   object
#  2   Description       1000 non-null   object
#  3   Release_Year      1000 non-null   int64
#  4   Language_Id       1000 non-null   int64
#  5   Rental_Duration   1000 non-null   int64
#  6   Rental_Rate       1000 non-null   float64
#  7   Length            1000 non-null   int64
#  8   Replacement_Cost  1000 non-null   float64
#  9   Rating            1000 non-null   object
#  10  Special_Features  1000 non-null   object
#  11  Last_Update       1000 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 93.9+ KB

# %%
alquileres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rental_Id     1000 non-null   int64
#  1   Rental_Date   1000 non-null   object
#  2   Inventory_Id  1000 non-null   int64
#  3   Customer_Id   1000 non-null   int64
#  4   Return_Date   1000 non-null   object
#  5   Staff_Id      1000 non-null   int64
#  6   Last_Update   1000 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 54.8+ KB

# %%
alquileres.columns
# Out:
# Index(['Rental_Id', 'Rental_Date', 'Inventory_Id', 'Customer_Id',
#        'Return_Date', 'Staff_Id', 'Last_Update'],
#       dtype='object')

# %%
alquileres.drop(columns =['Customer_Id','Staff_Id'],inplace=True)
# borro foreign keys que no necesito:

# %%
alquileres.columns
# Out:
# Index(['Rental_Id', 'Rental_Date', 'Inventory_Id', 'Return_Date',
#        'Last_Update'],
#       dtype='object')

# %%
alquileres.Last_Update=pd.to_datetime(alquileres.Last_Update, format='%Y-%m-%d')
# convierto a date time la columna Last Update

# %%
actores.Last_Update=pd.to_datetime(actores.Last_Update, format='%Y-%m-%d')
# convierto a date time la columna Last Update

# %%
peliculas.Last_Update=pd.to_datetime(peliculas.Last_Update, format='%Y-%m-%d')
# convierto a date time la columna Last Update

# %%
alquileres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rental_Id     1000 non-null   int64
#  1   Rental_Date   1000 non-null   object
#  2   Inventory_Id  1000 non-null   int64
#  3   Return_Date   1000 non-null   object
#  4   Last_Update   1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 39.2+ KB

# %%
actores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Actor_Id     200 non-null    int64
#  1   First_Name   200 non-null    object
#  2   Last_Name    200 non-null    object
#  3   Last_Update  200 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 6.4+ KB

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film_Id           1000 non-null   int64
#  1   Title             1000 non-null   object
#  2   Description       1000 non-null   object
#  3   Release_Year      1000 non-null   int64
#  4   Language_Id       1000 non-null   int64
#  5   Rental_Duration   1000 non-null   int64
#  6   Rental_Rate       1000 non-null   float64
#  7   Length            1000 non-null   int64
#  8   Replacement_Cost  1000 non-null   float64
#  9   Rating            1000 non-null   object
#  10  Special_Features  1000 non-null   object
#  11  Last_Update       1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 93.9+ KB

# %%
categorias = categorias.rename(columns={'Name': 'Genero'})

# %%
categorias.columns
# Out:
# Index(['Category_Id', 'Genero', 'Last_Update'], dtype='object')

# %%
alquileres.Rental_Date=pd.to_datetime(alquileres.Rental_Date, format='%Y-%m-%d')

# %%
alquileres.Return_Date=pd.to_datetime(alquileres.Return_Date, format='%Y-%m-%d')

# %%
categorias.columns
# Out:
# Index(['Category_Id', 'Genero', 'Last_Update'], dtype='object')

# %%
peliculas.columns
# Out:
# Index(['Film_Id', 'Title', 'Description', 'Release_Year', 'Language_Id',
#        'Rental_Duration', 'Rental_Rate', 'Length', 'Replacement_Cost',
#        'Rating', 'Special_Features', 'Last_Update'],
#       dtype='object')

# %%
antiguo.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Title', 'Release_Year', 'Category_Id'], dtype='object')

# %%
categorias
# Out:
#     Category_Id       Genero          Last_Update
# 0             1       Action  2006-02-15 04:46:27
# 1             2    Animation  2006-02-15 04:46:27
# 2             3     Children  2006-02-15 04:46:27
# 3             4     Classics  2006-02-15 04:46:27
# 4             5       Comedy  2006-02-15 04:46:27
# 5             6  Documentary  2006-02-15 04:46:27
# 6             7        Drama  2006-02-15 04:46:27
# 7             8       Family  2006-02-15 04:46:27
# 8             9      Foreign  2006-02-15 04:46:27
# 9            10        Games  2006-02-15 04:46:27
# 10           11       Horror  2006-02-15 04:46:27
# 11           12        Music  2006-02-15 04:46:27
# 12           13          New  2006-02-15 04:46:27
# 13           14       Sci-Fi  2006-02-15 04:46:27
# 14           15       Sports  2006-02-15 04:46:27
# 15           16       Travel  2006-02-15 04:46:27

# %%
len(antiguo.Title.unique())
# Out:
# 614

# %%
len(peliculas.Title.unique())
# Out:
# 1000

# %%
peliculas.columns
# Out:
# Index(['Film_Id', 'Title', 'Description', 'Release_Year', 'Language_Id',
#        'Rental_Duration', 'Rental_Rate', 'Length', 'Replacement_Cost',
#        'Rating', 'Special_Features', 'Last_Update'],
#       dtype='object')

# %%
antiguo.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Title', 'Release_Year', 'Category_Id'], dtype='object')

# %%
categorias.columns
# Out:
# Index(['Category_Id', 'Genero', 'Last_Update'], dtype='object')

# %%
film_category = pd.merge(antiguo, categorias, on='Category_Id')

# %%
film_category
# Out:
#     First_Name Last_Name              Title  Release_Year  Category_Id  \
# 0     PENELOPE   GUINESS   ACADEMY DINOSAUR          2006            6
# 1         NICK  WAHLBERG   ADAPTATION HOLES          2006            6
# 2           ED     CHASE   ARMY FLINTSTONES          2006            6
# 3           ED     CHASE     FRENCH HOLIDAY          2006            6
# 4           ED     CHASE     HALLOWEEN NUTS          2006            6
# ..         ...       ...                ...           ...          ...
# 995        VAL    BOLGER        CHITTY LOCK          2006            7
# 996        VAL    BOLGER  DALMATIONS SWEDEN          2006            7
# 997        VAL    BOLGER      PATHS CONTROL          2006            7
# 998        TOM  MCKELLEN  NECKLACE OUTBREAK          2006            7
# 999        TOM  MCKELLEN     SPICE SORORITY          2006            7
#
#           Genero          Last_Update
# 0    Documentary  2006-02-15 04:46:27
# ...

# %%
peliculas.columns
# Out:
# Index(['Film_Id', 'Title', 'Description', 'Release_Year', 'Language_Id',
#        'Rental_Duration', 'Rental_Rate', 'Length', 'Replacement_Cost',
#        'Rating', 'Special_Features', 'Last_Update'],
#       dtype='object')

# %%
actores.columns
# Out:
# Index(['Actor_Id', 'First_Name', 'Last_Name', 'Last_Update'], dtype='object')

# %%
peliculas['Rental_Rate'] = peliculas['Rental_Rate'].astype(int)

# %%
peliculas.Rental_Rate
# Out:
# 0      0
# 1      4
# 2      2
# 3      2
# 4      2
#       ..
# 995    0
# 996    0
# 997    0
# 998    2
# 999    4
# Name: Rental_Rate, Length: 1000, dtype: int32

# %%
alquileres
# Out:
#      Rental_Id         Rental_Date  Inventory_Id         Return_Date  \
# 0            1 2005-05-24 22:53:30           367 2005-05-26 22:04:30
# 1            2 2005-05-24 22:54:33          1525 2005-05-28 19:40:33
# 2            3 2005-05-24 23:03:39          1711 2005-06-01 22:12:39
# 3            4 2005-05-24 23:04:41          2452 2005-06-03 01:43:41
# 4            5 2005-05-24 23:05:21          2079 2005-06-02 04:33:21
# ..         ...                 ...           ...                 ...
# 995        997 2005-05-31 00:08:25          4243 2005-06-02 00:17:25
# 996        998 2005-05-31 00:16:57          3395 2005-06-01 22:41:57
# 997        999 2005-05-31 00:25:10          4433 2005-06-03 06:05:10
# 998       1000 2005-05-31 00:25:56          1774 2005-06-08 19:42:56
# 999       1001 2005-05-31 00:46:31          1498 2005-06-06 06:14:31
#
#             Last_Update
# 0   2006-02-15 21:30:53
# 1   2006-02-15 21:30:53
# 2   2006-02-15 21:30:53
# 3   2006-02-15 21:30:53
# ...

# %%
alquileres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rental_Id     1000 non-null   int64
#  1   Rental_Date   1000 non-null   datetime64[ns]
#  2   Inventory_Id  1000 non-null   int64
#  3   Return_Date   1000 non-null   datetime64[ns]
#  4   Last_Update   1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), int64(2)
# memory usage: 39.2 KB

# %%
antiguo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   First_Name    1000 non-null   object
#  1   Last_Name     1000 non-null   object
#  2   Title         1000 non-null   object
#  3   Release_Year  1000 non-null   int64
#  4   Category_Id   1000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB

# %%
categorias.columns
# Out:
# Index(['Category_Id', 'Genero', 'Last_Update'], dtype='object')

# %%
antiguo.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Title', 'Release_Year', 'Category_Id'], dtype='object')

# %%
peliculas.columns
# Out:
# Index(['Film_Id', 'Title', 'Description', 'Release_Year', 'Language_Id',
#        'Rental_Duration', 'Rental_Rate', 'Length', 'Replacement_Cost',
#        'Rating', 'Special_Features', 'Last_Update', 'Genero', 'category'],
#       dtype='object')
